# %% [markdown]
# ## Histograma para congreso

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
import matplotlib as mpl
import matplotlib.ticker as ticker
import matplotlib.patheffects as path_effects

# %%
cbx_95 =  np.array([912, 498, 542, 1077, 870, 653, 475, 599])
nacl_83 = np.array([1734, 2037, 1533, 2321, 1322, 1291, 2071, 1541])
tma_35 = np.array([177, 215, 425, 323, 164, 127, 219, 176])
quinina_84 = np.array([1658, 1719, 2227, 1625, 504, 1532, 1644, 1675])

# cbx_95 =  np.array([913, 499, 543, 1078, 871, 654, 476, 600])
# nacl_83 = np.array([1735, 2038, 1534, 2322, 1323, 1292, 2072, 1542])
# tma_35 = np.array([178, 216, 426, 324, 165, 128, 220, 177])
# quinina_84 = np.array([1659, 1720, 2228, 1626, 505, 1533, 1645, 1676])

# %%
print(np.sum(cbx_95))
print(np.sum(nacl_83))
print(np.sum(tma_35))
print(np.sum(np.sum(quinina_84)))
prom = (np.sum(cbx_95)+np.sum(nacl_83)+np.sum(tma_35)+np.sum(quinina_84))/4
prom
# Out:
# 5626
# 13850
# 1826
# 12584
# 8471.5

# %%
CCfig, ax = plt.subplots()

labels = ['95 CBX','83 NaCl','35 TMA','84 QUININE']
counts = [5626 , 13850, 1826, 12584]

# Add spines
ax.spines[['top','left','right']].set_visible(False)
# ax.spines['right'].set_linewidth(1.1)
# ax.spines["top"].set(visible = False)
# ax.spines["right"].set(visible = False)


# Add grid and axis labels
ax.grid(True, color = "lightgrey", ls = ":")
ax.set_ylabel("Slow Wave ripples detected")

ax.bar(
	labels, 
    counts, 
    ec = "#87d1e1", 
    lw = .75, 
    color = "#87d1e1", 
    zorder = 3, 
    width = 0.5
)

# Annotate the ratio

for index, y in enumerate(counts):
    ax.annotate(
        xy = (index, y),
        text = f"{y}",
        xytext = (0, 7),
        textcoords = "offset points",
        size = 10,
        color = "#660033",
        ha = "center",
        va = "center",
        weight = "bold"
    )

xticks_ = ax.xaxis.set_ticks(
    ticks = labels,
    labels = labels,
    # rotation = 90
)

plt.title("Number of slow wave ripples detected by animal") 
plt.xlabel("Animal ID")
plt.show()

# %%
CCfig, ax = plt.subplots()
# labels = ['95 CBX','83 NaCl','35 TMA','84 QUININA']
labels = ['1','2','3','4']
ele_name = ['HAD1','HADP2','HAD3','HADP4','HPD5','HPDP6','HPD7','HPDP8']

cbx_95 =  np.array([912, 498, 542, 1077, 870, 653, 475, 599])
nacl_83 = np.array([1734, 2037, 1533, 2321, 1322, 1291, 2071, 1541])
tma_35 = np.array([177, 215, 425, 323, 164, 127, 219, 176])
quinina_84 = np.array([1658, 1719, 2227, 1625, 504, 1532, 1644, 1675])


n = len(ele_name)
r = np.arange(n) 
width = 0.25

# Add spines
ax.spines[['top','left','right']].set_visible(False)

# Add grid and axis labels
ax.grid(True, color = "lightgrey", ls = ":")
ax.set_ylabel("Slow Wave ripples detected")

plt.bar(r, cbx_95, color = '#f9ad81', 
        width = width, edgecolor = '#f9ad81', zorder = 3, 
        label='1') 
plt.bar(r + width,nacl_83, color = '#cbd8ff', zorder = 3,
        width = width, edgecolor = '#cbd8ff', 
        label='2') 
plt.bar(r + 2*width, tma_35, color = '#850766', zorder = 3,
        width = width, edgecolor = '#850766', 
        label='3') 
plt.bar(r + 3*width,quinina_84, color = '#837dbc', zorder = 3, 
        width = width, edgecolor = '#837dbc', 
        label='4 ') 

plt.xlabel("Electrode name") 
plt.ylabel("Slow wave ripple detected") 
plt.title("Number of slow wave detected by electrode") 
  
# plt.grid(linestyle='--') 
plt.xticks(r + width,ele_name) 
plt.legend(loc='upper right', fontsize="7") 

plt.show()

# %%
CCfig, ax = plt.subplots()
labels = ['95 CBX','83 NaCl','35 TMA','84 QUININA']
ele_name = ['HAD1','HADP2','HAD3','HADP4','HPD5','HPDP6','HPD7','HPDP8']
cbx_95 =  np.array([1134, 692, 929, 1247, 1190, 822, 661, 674])
nacl_83 = np.array([1536, 2580, 1401, 4297, 1880, 1639, 2583, 2737])
tma_35 = np.array([539, 579, 1033, 792, 453, 258, 605, 411])
quinina_84 = np.array([1126, 1301, 1500, 1216, 609, 813, 1334, 1398])

n = len(ele_name)
r = np.arange(n) 
width = 0.25

# Add spines
ax.spines[['top','left','right']].set_visible(False)

# Add grid and axis labels
ax.grid(True, color = "lightgrey", ls = ":")

plt.bar(r, cbx_95, color = '#f9ad81', 
        width = width, edgecolor = '#f9ad81', zorder = 3, 
        label='1') 
plt.bar(r + width,nacl_83, color = '#cbd8ff', zorder = 3,
        width = width, edgecolor = '#cbd8ff', 
        label='2') 
plt.bar(r + 2*width, tma_35, color = '#850766', zorder = 3,
        width = width, edgecolor = '#850766', 
        label='3') 
plt.bar(r + 3*width,quinina_84, color = '#837dbc', zorder = 3, 
        width = width, edgecolor = '#837dbc', 
        label='4') 

plt.xlabel("Electrode name") 
plt.ylabel("Possible HFO detected") 
plt.title("Number of HFO detected by electrode") 
  
# plt.grid(linestyle='--') 
plt.xticks(r + width,ele_name) 
plt.legend(loc='upper right', fontsize="7") 

plt.show()

# %%
#SWR detectadas por animal 

CCfig, ax = plt.subplots()


labels = ['1','2','3','4','5','6','7','8']
cbx_84 =  np.array([1444, 1731, 1293, 2768, 973, 1432, 1719, 1855])
cbx_95 =  np.array([1134, 692, 929, 1247, 1190, 822, 661, 674])

nacl_83 = np.array([1536, 2580, 1401, 4297, 1880, 1639, 2583, 2737])
nacl_89 = np.array([7, 52, 12, 75, 105, 198, 79, 177])

tma_35 = np.array([539, 579, 1033, 792, 453, 258, 605, 411])
tma_91 = np.array([149, 31, 653, 233, 114, 82, 27, 174])

quinina_79 = np.array([1275, 604, 699, 179, 795, 345, 513, 1182])
quinina_84 = np.array([1126, 1301, 1500, 1216, 609, 813, 1334, 1398])

counts = [np.sum(cbx_95) , np.sum(nacl_83), np.sum(tma_35), np.sum(quinina_84), np.sum(cbx_84) , np.sum(nacl_89), np.sum(tma_91), np.sum(quinina_79)]

total = np.sum([cbx_84, cbx_95, tma_91, tma_35, quinina_79, quinina_84, nacl_83, nacl_89])
print(total)
# Add spines
ax.spines[['top','left','right']].set_visible(False)
# ax.spines['right'].set_linewidth(1.1)
# ax.spines["top"].set(visible = False)
# ax.spines["right"].set(visible = False)


# Add grid and axis labels
ax.grid(True, color = "lightgrey", ls = ":")
# ax.set_ylabel("Possible HFO detected")

ax.bar(
	labels, 
    counts, 
    ec = "#87d1e1", 
    lw = .75, 
    color = "#87d1e1", 
    zorder = 3, 
    width = 0.5
)

# Annotate the ratio

for index, y in enumerate(counts):
    ax.annotate(
        xy = (index, y),
        text = f"{y}",
        xytext = (0, 7),
        textcoords = "offset points",
        size = 10,
        color = "#660033",
        ha = "center",
        va = "center",
        weight = "bold"
    )

xticks_ = ax.xaxis.set_ticks(
    ticks = labels,
    labels = labels,
    # rotation = 90
)

plt.title("Number of SWR detected by animal") 
plt.xlabel("Animal ID")
plt.show()
# Out:
# 60944

# %%
import pandas as pd

# %%
df_CBX95_1 = pd.read_csv('D:/DataFrames SR/experimental CBX proyecto/FR-95_CBX/HAD1/FR-95_CBX_HAD1_SR.csv')
df_CBX95_2 = pd.read_csv('D:/DataFrames SR/experimental CBX proyecto/FR-95_CBX/HADP2/FR-95_CBX_HADP2_SR.csv')
df_CBX95_3 = pd.read_csv('D:/DataFrames SR/experimental CBX proyecto/FR-95_CBX/HAD3/FR-95_CBX_HAD3_SR.csv')
df_CBX95_4 = pd.read_csv('D:/DataFrames SR/experimental CBX proyecto/FR-95_CBX/HADp4/FR-95_CBX_HADp4_SR.csv')
df_CBX95_5 = pd.read_csv('D:/DataFrames SR/experimental CBX proyecto/FR-95_CBX/HPD5/FR-95_CBX_HPD5_SR.csv')
df_CBX95_6 = pd.read_csv('D:/DataFrames SR/experimental CBX proyecto/FR-95_CBX/HPDp6/FR-95_CBX_HPDp6_SR.csv')
df_CBX95_7 = pd.read_csv('D:/DataFrames SR/experimental CBX proyecto/FR-95_CBX/HPD7/FR-95_CBX_HPD7_SR.csv')
df_CBX95_8 = pd.read_csv('D:/DataFrames SR/experimental CBX proyecto/FR-95_CBX/HPDp8/FR-95_CBX_HPDp8_SR.csv')


df_NACl83_1 = pd.read_csv('D:/DataFrames SR/experimental NaCl proyecto/FR-83_NaCl/HAD1/FR-83_NaCl_HAD1_SR.csv')
df_NACl83_2 = pd.read_csv('D:/DataFrames SR/experimental NaCl proyecto/FR-83_NaCl/HADP2/FR-83_NaCl_HADP2_SR.csv')
df_NACl83_3 = pd.read_csv('D:/DataFrames SR/experimental NaCl proyecto/FR-83_NaCl/HAD3/FR-83_NaCl_HAD3_SR.csv')
df_NACl83_4 = pd.read_csv('D:/DataFrames SR/experimental NaCl proyecto/FR-83_NaCl/HADp4/FR-83_NaCl_HADp4_SR.csv')
df_NACl83_5 = pd.read_csv('D:/DataFrames SR/experimental NaCl proyecto/FR-83_NaCl/HPD5/FR-83_NaCl_HPD5_SR.csv')
df_NACl83_6 = pd.read_csv('D:/DataFrames SR/experimental NaCl proyecto/FR-83_NaCl/HPDp6/FR-83_NaCl_HPDp6_SR.csv')
df_NACl83_7 = pd.read_csv('D:/DataFrames SR/experimental NaCl proyecto/FR-83_NaCl/HPD7/FR-83_NaCl_HPD7_SR.csv')
df_NACl83_8 = pd.read_csv('D:/DataFrames SR/experimental NaCl proyecto/FR-83_NaCl/HPDp8/FR-83_NaCl_HPDp8_SR.csv')

df_Q84_1 = pd.read_csv('D:/DataFrames SR/experimental QUININA proyecto/FR-84_QUININA/HAD1/FR-84_QUININA_HAD1_SR.csv')
df_Q84_2 = pd.read_csv('D:/DataFrames SR/experimental QUININA proyecto/FR-84_QUININA/HADP2/FR-84_QUININA_HADP2_SR.csv')
df_Q84_3 = pd.read_csv('D:/DataFrames SR/experimental QUININA proyecto/FR-84_QUININA/HAD3/FR-84_QUININA_HAD3_SR.csv')
df_Q84_4 = pd.read_csv('D:/DataFrames SR/experimental QUININA proyecto/FR-84_QUININA/HADp4/FR-84_QUININA_HADp4_SR.csv')
df_Q84_5 = pd.read_csv('D:/DataFrames SR/experimental QUININA proyecto/FR-84_QUININA/HPD5/FR-84_QUININA_HPD5_SR.csv')
df_Q84_6 = pd.read_csv('D:/DataFrames SR/experimental QUININA proyecto/FR-84_QUININA/HPDp6/FR-84_QUININA_HPDp6_SR.csv')
df_Q84_7 = pd.read_csv('D:/DataFrames SR/experimental QUININA proyecto/FR-84_QUININA/HPD7/FR-84_QUININA_HPD7_SR.csv')
df_Q84_8 = pd.read_csv('D:/DataFrames SR/experimental QUININA proyecto/FR-84_QUININA/HPDp8/FR-84_QUININA_HPDp8_SR.csv')

df_T35_1 = pd.read_csv('D:/DataFrames SR/experimental TMA proyecto/FR-35_TMA/HAD1/FR-35_TMA_HAD1_SR.csv')
df_T35_2 = pd.read_csv('D:/DataFrames SR/experimental TMA proyecto/FR-35_TMA/HADP2/FR-35_TMA_HADP2_SR.csv')
df_T35_3 = pd.read_csv('D:/DataFrames SR/experimental TMA proyecto/FR-35_TMA/HAD3/FR-35_TMA_HAD3_SR.csv')
df_T35_4 = pd.read_csv('D:/DataFrames SR/experimental TMA proyecto/FR-35_TMA/HADp4/FR-35_TMA_HADp4_SR.csv')
df_T35_5 = pd.read_csv('D:/DataFrames SR/experimental TMA proyecto/FR-35_TMA/HPD5/FR-35_TMA_HPD5_SR.csv')
df_T35_6 = pd.read_csv('D:/DataFrames SR/experimental TMA proyecto/FR-35_TMA/HPDp6/FR-35_TMA_HPDp6_SR.csv')
df_T35_7 = pd.read_csv('D:/DataFrames SR/experimental TMA proyecto/FR-35_TMA/HPD7/FR-35_TMA_HPD7_SR.csv')
df_T35_8 = pd.read_csv('D:/DataFrames SR/experimental TMA proyecto/FR-35_TMA/HPDp8/FR-35_TMA_HPDp8_SR.csv')

# %%
CCfig, ax = plt.subplots()
dur = [df_CBX95_1['Duration'],df_CBX95_2['Duration'],df_CBX95_3['Duration'],df_CBX95_4['Duration'],df_CBX95_5['Duration'],df_CBX95_6['Duration'],df_CBX95_7['Duration'],df_CBX95_8['Duration']]
plt.boxplot(dur, labels=ele_name)

ax.spines[['top','left','right']].set_visible(False)
ax.grid(True, color = "lightgrey", ls = ":")

plt.title("Duration of possible HFO in Animal Id. 1") 
plt.xlabel("Electrode name")
plt.ylabel("Duration time (s)")
# Out:
# Text(0, 0.5, 'Duration time (s)')

# %%
CCfig, ax = plt.subplots()
dur = [df_NACl83_1['Duration'],df_NACl83_2['Duration'],df_NACl83_3['Duration'],df_NACl83_4['Duration'],df_NACl83_5['Duration'],df_NACl83_6['Duration'],df_NACl83_7['Duration'],df_NACl83_8['Duration']]
plt.boxplot(dur, labels=ele_name)

ax.spines[['top','left','right']].set_visible(False)
ax.grid(True, color = "lightgrey", ls = ":")

plt.title("Duration of possible in Animal Id. 2") 
plt.xlabel("Electrode name")
plt.ylabel("Duration time (s)")
# Out:
# Text(0, 0.5, 'Duration time (s)')

# %%
CCfig, ax = plt.subplots()
dur = [df_Q84_1['Duration'],df_Q84_2['Duration'],df_Q84_3['Duration'],df_Q84_4['Duration'],df_Q84_5['Duration'],df_Q84_6['Duration'],df_Q84_7['Duration'],df_Q84_8['Duration']]
plt.boxplot(dur, labels=ele_name)

ax.spines[['top','left','right']].set_visible(False)
ax.grid(True, color = "lightgrey", ls = ":")

plt.title("Duration of possible HFO in Animal Id. 4") 
plt.xlabel("Electrode name")
plt.ylabel("Duration time (s)")
# Out:
# Text(0, 0.5, 'Duration time (s)')

# %%
CCfig, ax = plt.subplots()
dur = [df_T35_1['Duration'],df_T35_2['Duration'],df_T35_3['Duration'],df_T35_4['Duration'],df_T35_5['Duration'],df_T35_6['Duration'],df_T35_7['Duration'],df_T35_8['Duration']]
plt.boxplot(dur, labels=ele_name)

ax.spines[['top','left','right']].set_visible(False)
ax.grid(True, color = "lightgrey", ls = ":")

plt.title("Duration of possible HFO in Animal Id. 3") 
plt.xlabel("Electrode name")
plt.ylabel("Duration time (s)")
# Out:
# Text(0, 0.5, 'Duration time (s)')

# %% [markdown]
# ## Predoctoral

# %%
#SWR detectadas por animal 

CCfig, ax = plt.subplots()


labels = ['1','2','3','4','5','6','7','8']
cbx_84 =  np.array([1444, 1731, 1293, 2768, 973, 1432, 1719, 1855])
cbx_95 =  np.array([1134, 692, 929, 1247, 1190, 822, 661, 674])

nacl_83 = np.array([1536, 2580, 1401, 4297, 1880, 1639, 2583, 2737])
nacl_89 = np.array([7, 52, 12, 75, 105, 198, 79, 177])

tma_35 = np.array([539, 579, 1033, 792, 453, 258, 605, 411])
tma_91 = np.array([149, 31, 653, 233, 114, 82, 27, 174])

quinina_79 = np.array([1275, 604, 699, 179, 795, 345, 513, 1182])
quinina_84 = np.array([1126, 1301, 1500, 1216, 609, 813, 1334, 1398])

counts = [np.sum(cbx_95) , np.sum(nacl_83), np.sum(tma_35), np.sum(quinina_84), np.sum(cbx_84) , np.sum(nacl_89), np.sum(tma_91), np.sum(quinina_79)]

total = np.sum([cbx_84, cbx_95, tma_91, tma_35, quinina_79, quinina_84, nacl_83, nacl_89])
print(total)
# Add spines
ax.spines[['top','left','right']].set_visible(False)
# ax.spines['right'].set_linewidth(1.1)
# ax.spines["top"].set(visible = False)
# ax.spines["right"].set(visible = False)


# Add grid and axis labels
ax.grid(True, color = "lightgrey", ls = ":")
# ax.set_ylabel("Possible HFO detected")

ax.bar(
	labels, 
    counts, 
    ec = "#87d1e1", 
    lw = .75, 
    color = "#87d1e1", 
    zorder = 3, 
    width = 0.5
)

# Annotate the ratio

for index, y in enumerate(counts):
    ax.annotate(
        xy = (index, y),
        text = f"{y}",
        xytext = (0, 7),
        textcoords = "offset points",
        size = 10,
        color = "#660033",
        ha = "center",
        va = "center",
        weight = "bold"
    )

xticks_ = ax.xaxis.set_ticks(
    ticks = labels,
    labels = labels,
    # rotation = 90
)

plt.title("Number of SWR detected by animal") 
plt.xlabel("Animal ID")
plt.show()
# Out:
# 60944

# %%
cbx_84 =  np.array([121,150,133,105,17,75,108,142]) #851
cbx_95 =  np.array([104,98,90,66,72,122,78,58]) #688

nacl_83 = np.array([113,70,55,187,66,60,85,0]) #636
nacl_89 = np.array([0,3,0,7,11,15,4,74]) #114

tma_35 = np.array([67,17,79,12,19,20,10,14]) # 238
tma_91 = np.array([5,2,13,7,3,0,2,7]) #39

quinina_79 = np.array([99,22,60,18,59,25,24,66]) #375
quinina_84 = np.array([38,55,64,36,13,12,64,31]) # 313

total = np.array([850, 687,636,114,238,39,375,313])

# %%
print(np.sum(cbx_84))
print(np.sum(cbx_95))
print(np.sum(nacl_83))
print(np.sum(nacl_89))
print(np.sum(tma_35))
print(np.sum(tma_91))
print(np.sum(quinina_79))
print(np.sum(quinina_84))
# Out:
# 851
# 688
# 636
# 114
# 238
# 39
# 373
# 313

# %%
total = np.sum([cbx_84, cbx_95, tma_91, tma_35, quinina_79, quinina_84, nacl_83, nacl_89])
print(total)
# Out:
# 3252

# %%
fig = plt.figure(figsize=(10,3), dpi=200)
CCfig, ax = plt.subplots()
labels = ['1','2','3','4','5','6','7','8']
ele_name = ['HAD1','HADP2','HAD3','HADP4','HPD5','HPDP6','HPD7','HPDP8']

cbx_84 =  np.array([121,150,133,105,17,75,108,142]) #851
cbx_95 =  np.array([104,98,90,66,72,122,78,58]) #688

nacl_83 = np.array([113,70,55,187,66,60,85,0]) #636
nacl_89 = np.array([0,3,0,7,11,15,4,74]) #114

tma_35 = np.array([67,17,79,12,19,20,10,14]) # 238
tma_91 = np.array([5,2,13,7,3,0,2,7]) #39

quinina_79 = np.array([99,22,60,18,59,25,24,66]) #375
quinina_84 = np.array([38,55,64,36,13,12,64,31]) # 313


n = len(ele_name)
r = np.arange(n) 
width = 0.12

# Add spines
ax.spines[['top','left','right']].set_visible(False)

# Add grid and axis labels
ax.grid(True, color = "lightgrey", ls = ":")

plt.bar(r, cbx_84, color = '#5F9EA0', 
        width = width, edgecolor = '#5F9EA0', zorder = 3, 
        label='1') 
plt.bar(r + width, cbx_95, color = '#f9ad81', 
        width = width, edgecolor = '#f9ad81', zorder = 3, 
        label='2') 

plt.bar(r + 2*width,nacl_83, color = '#cbd8ff', zorder = 3,
        width = width, edgecolor = '#cbd8ff', 
        label='3') 
plt.bar(r + 3*width,nacl_89, color = '#DC143C', zorder = 3,
        width = width, edgecolor = '#DC143C', 
        label='4') 

plt.bar(r + 4*width, tma_35, color = '#850766', zorder = 3,
        width = width, edgecolor = '#850766', 
        label='5') 
plt.bar(r + 5*width, tma_91, color = '#BA55D3', zorder = 3,
        width = width, edgecolor = '#BA55D3', 
        label='6') 

plt.bar(r + 6*width,quinina_79, color = '#837dbc', zorder = 3, 
        width = width, edgecolor = '#837dbc', 
        label='7') 
plt.bar(r + 7*width,quinina_84, color = '#87CEEB', zorder = 3, 
        width = width, edgecolor = '#87CEEB', 
        label='8') 



plt.xlabel("Electrode name") 
plt.ylabel("Possible true FR detected") 
plt.title("Number of FR by electrode") 
  
# plt.grid(linestyle='--') 
plt.xticks(r + width,ele_name) 
plt.legend(loc='upper right', fontsize="7") 

plt.show()

# %%
cbx_84 =  np.array([1314,1554,1136,2651,946,1331,1595,1692]) # 12219
cbx_95 =  np.array([1026,583,832,1177,1115,699,580,613]) # 6625

nacl_83 = np.array([1406,2509,1343,4106,1813,1578,2497,1221]) # 16473
nacl_89 = np.array([6,48,11,66,93,182,74,102]) # 582

tma_35 = np.array([469,561,953,779,433,237,594,397]) # 4423
tma_91 = np.array([142,28,639,225,110,81,24,166]) #1415

quinina_79 = np.array([1174,578,636,157,734,319,486,1111]) # 5195
quinina_84 = np.array([1086,1244,1435,1178,595,800,1269,1366]) # 8973

print(np.sum(cbx_84))
print(np.sum(cbx_95))
print(np.sum(nacl_83))
print(np.sum(nacl_89))
print(np.sum(tma_35))
print(np.sum(tma_91))
print(np.sum(quinina_79))
print(np.sum(quinina_84))
# Out:
# 12219
# 6625
# 16473
# 582
# 4423
# 1415
# 5195
# 8973

# %%
fig = plt.figure(figsize=(10,3), dpi=200)
CCfig, ax = plt.subplots()
labels = ['1','2','3','4','5','6','7','8']
ele_name = ['HAD1','HADP2','HAD3','HADP4','HPD5','HPDP6','HPD7','HPDP8']

cbx_84 =  np.array([1314,1554,1136,2651,946,1331,1595,1692]) # 12219
cbx_95 =  np.array([1026,583,832,1177,1115,699,580,613]) # 6625

nacl_83 = np.array([1406,2509,1343,4106,1813,1578,2497,1221]) # 16473
nacl_89 = np.array([6,48,11,66,93,182,74,102]) # 582

tma_35 = np.array([469,561,953,779,433,237,594,397]) # 4423
tma_91 = np.array([142,28,639,225,110,81,24,166]) #1415

quinina_79 = np.array([1174,578,636,157,734,319,486,1111]) # 5195
quinina_84 = np.array([1086,1244,1435,1178,595,800,1269,1366]) # 8973


n = len(ele_name)
r = np.arange(n) 
width = 0.12

# Add spines
ax.spines[['top','left','right']].set_visible(False)

# Add grid and axis labels
ax.grid(True, color = "lightgrey", ls = ":")

plt.bar(r, cbx_84, color = '#5F9EA0', 
        width = width, edgecolor = '#5F9EA0', zorder = 3, 
        label='1') 
plt.bar(r + width, cbx_95, color = '#f9ad81', 
        width = width, edgecolor = '#f9ad81', zorder = 3, 
        label='2') 

plt.bar(r + 2*width,nacl_83, color = '#cbd8ff', zorder = 3,
        width = width, edgecolor = '#cbd8ff', 
        label='3') 
plt.bar(r + 3*width,nacl_89, color = '#DC143C', zorder = 3,
        width = width, edgecolor = '#DC143C', 
        label='4') 

plt.bar(r + 4*width, tma_35, color = '#850766', zorder = 3,
        width = width, edgecolor = '#850766', 
        label='5') 
plt.bar(r + 5*width, tma_91, color = '#BA55D3', zorder = 3,
        width = width, edgecolor = '#BA55D3', 
        label='6') 

plt.bar(r + 6*width,quinina_79, color = '#837dbc', zorder = 3, 
        width = width, edgecolor = '#837dbc', 
        label='7') 
plt.bar(r + 7*width,quinina_84, color = '#87CEEB', zorder = 3, 
        width = width, edgecolor = '#87CEEB', 
        label='8') 



plt.xlabel("Electrode name") 
plt.ylabel("Possible false FR detected") 
plt.title("Number of FR by electrode") 
  
# plt.grid(linestyle='--') 
plt.xticks(r + width,ele_name) 
plt.legend(loc='upper right', fontsize="7") 

plt.show()
